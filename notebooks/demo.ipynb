# %%
# Add relevant Jupyter notebook extensions 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# You can double-check your Python path like this...
import sys  
print(sys.path)
sys.path.append('/Users/lachydow/B1 Computing Lab/b1-coding-practical-mt24/uuv_mission')
# Out:
# ['/opt/anaconda3/lib/python311.zip', '/opt/anaconda3/lib/python3.11', '/opt/anaconda3/lib/python3.11/lib-dynload', '', '/Users/lachydow/.venvs/test_venv/lib/python3.11/site-packages', '/Users/lachydow/B1 Computing Lab/b1-coding-practical-mt24/uuv_mission', '/Users/lachydow/B1 Computing Lab/b1-coding-practical-mt24/uuv_mission', '/Users/lachydow/B1 Computing Lab/b1-coding-practical-mt24/uuv_mission', '/Users/lachydow/B1 Computing Lab/b1-coding-practical-mt24/uuv_mission', '/Users/lachydow/B1 Computing Lab/b1-coding-practical-mt24/uuv_mission', '/Users/lachydow/B1 Computing Lab/b1-coding-practical-mt24/uuv_mission', '/Users/lachydow/B1 Computing Lab/b1-coding-practical-mt24/uuv_mission', '/Users/lachydow/B1 Computing Lab/b1-coding-practical-mt24', '/Users/lachydow/B1 Computing Lab/b1-coding-practical-mt24', '/Users/lachydow/B1 Computing Lab/b1-coding-practical-mt24', '/Users/lachydow/B1 Computing Lab/b1-coding-practical-mt24']

# %% [markdown]
# # Simulate closed-loop
# After implementing your control functionality, you can simulate the closed-loop with code that looks something like this...

# %%
# Import relevant modules
import sys
import os
sys.path.append('/Users/lachydow/B1 Computing Lab/b1-coding-practical-mt24')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from dataclasses import dataclass
# Import your custom modules
from control import PDController
from dynamic import Submarine, ClosedLoop, Mission
sub = Submarine()
controller = PDController()
# Instantiate your controller (depending on your implementation)
closed_loop = ClosedLoop(sub, controller)
#Load the mission from a CSV file
mission = Mission.from_csv("/Users/lachydow/B1 Computing Lab/b1-coding-practical-mt24/data/mission.csv") # You must implement this method in the Mission class
#Simulate the mission with random disturbances
trajectory = closed_loop.simulate_with_random_disturbances(mission)
#Plot the completed mission
trajectory.plot_completed_mission(mission)
